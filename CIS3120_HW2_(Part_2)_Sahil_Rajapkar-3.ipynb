# %%
# First we import the endpoint
# We will be using pandas dataframes to manipulate the data
from nba_api.stats.endpoints import playergamelog
from nba_api.stats.static import players
import pandas as pd
from pandas import DataFrame
import numpy as np

player_dict = players.get_players()

#print(player_dict)
# Use ternary operator or write function 
# Names are case sensitive

# If you want all seasons, you must import the SeasonAll parameter 
from nba_api.stats.library.parameters import SeasonAll

pd.set_option('display.max_columns', None) #this does it for all the players

gamelog_bron_all = playergamelog.PlayerGameLog(player_id='2544', season = SeasonAll.all)
df_bron_games_all = gamelog_bron_all.get_data_frames() #how is this a list???
#gamelog_bron_all.describe()
#df_bron_games_all1 = df_bron_games_all.drop(columns='SEASON_ID', inplace=True, axis=1)
#df_bron_games_all1 = df_bron_games_all.reshape(1322,27)
dfa_bron_games_all1 = np.array(df_bron_games_all) #now it's an array which means I can reshape
print(df_bron_games_all) #what is the shape of this list then
print(type(df_bron_games_all))


#df = pd.DataFrame(df_bron_games_all, columns=['MIN', 'FG_PCT','FTM','PTS','PLUS_MINUS'])
#print(df)

#SO WAIT THE LIST IS WHAT IS HAVING THE ISSUE REGARDING DIMENSION BUT I CONVERTED ALL THAT 
#JUST TO GET AN ARRAY THAT IS GOOD DIMENSION WISE BUT IS AN ARRAY NOT A LIST

#the array is 3-D
#df_bron_games_all.desribe()
#print(df_bron_games_all['MIN'].describe())
#bronstat = df_bron_games_all.describe(include='all')
#print(bronstat)
'''
print(dfa_bron_games_all1)
print(dfa_bron_games_all1.shape) #alright so we know it's 3-D but we want a 2-D array
print(type(dfa_bron_games_all1))
print("")
'''
'''
print("")
answer100 = dfa_bron_games_all1.reshape([1322,27])
print(answer100)
print(answer100.shape) 
print(type(answer100))
#bronstat = answer100.describe(include='all')
#print(bronstat)
'''
'''
type1 = answer100['MIN'].dtypes
print(type1)
'''
'''
df = DataFrame([[answer100]], columns= ['MIN', 'FG_PCT','FTM','PTS','PLUS_MINUS'])
desc100 = answer100['MIN', 'FG_PCT','FTM','PTS','PLUS_MINUS'].describe()
print(desc100)
'''                  
#bronstats = df.describe(include='all') won't work cause of 'all'
#print(bronstats)

'''
answer1 = np.arange(dfa_bron_games_all1).reshape((1322,27))
print(answer1)
print(answer1.shape)
'''
#print(dfa_bron_games_all1.isArray())
#answer1 = np.dfa_bron_games_all1.reshape(1322,27)
#print(answer1)
#df = DataFrame(answer1, columns= ['MIN', 'FG_PCT','FTM','PTS','PLUS_MINUS'])
#bronstats = df.describe(include='all')
#print(bronstats)

'''
need something that will do what I said in Sublime
#bronstat = df_bron_games_all.describe(include='all')
#print(bronstat)

stats = df.describe(include='all')
print (stats)

df = DataFrame(df_bron_games_all, columns= ['PTS', 'P','Year'])

stats = df.describe(include='all')
print (stats)
'''
gamelog_steph_all = playergamelog.PlayerGameLog(player_id='201939', season = SeasonAll.all)
df_steph_games_all = gamelog_steph_all.get_data_frames()
print(df_steph_games_all)

gamelog_kobe_all = playergamelog.PlayerGameLog(player_id='977', season = SeasonAll.all)
df_kobe_games_all = gamelog_kobe_all.get_data_frames()
print(df_kobe_games_all)

gamelog_mike_all = playergamelog.PlayerGameLog(player_id='893', season = SeasonAll.all)
df_mike_games_all = gamelog_mike_all.get_data_frames()
print(df_mike_games_all)

gamelog_shaq_all = playergamelog.PlayerGameLog(player_id='406', season = SeasonAll.all)
df_shaq_games_all = gamelog_shaq_all.get_data_frames()
print(df_shaq_games_all)

gamelog_kareem_all = playergamelog.PlayerGameLog(player_id='76003', season = SeasonAll.all)
df_kareem_games_all = gamelog_kareem_all.get_data_frames()
print(df_kareem_games_all)

gamelog_wilt_all = playergamelog.PlayerGameLog(player_id='76375', season = SeasonAll.all)
df_wilt_games_all = gamelog_wilt_all.get_data_frames()
print(df_wilt_games_all)

gamelog_magic_all = playergamelog.PlayerGameLog(player_id='77142', season = SeasonAll.all)
df_magic_games_all = gamelog_magic_all.get_data_frames()
print(df_magic_games_all)

gamelog_larry_all = playergamelog.PlayerGameLog(player_id='1449', season = SeasonAll.all)
df_larry_games_all = gamelog_larry_all.get_data_frames()
print(df_larry_games_all)

gamelog_kevin_all = playergamelog.PlayerGameLog(player_id='201142', season = SeasonAll.all)
df_kevin_games_all = gamelog_kevin_all.get_data_frames()
print(df_kevin_games_all)

'''
pd.concat([
    pd.concat([df_bron_games_all, df_steph_games_all], axis=1),
    pd.concat([df_kobe_games_all, df_mike_games_all], axis=1),
    pd.concat([df_shaq_games_all, df_kareem_games_all], axis=1),
    pd.concat([df_wilt_games_all, df_magic_games_all], axis=1),
    pd.concat([df_larry_games_all, df_kevin_games_all], axis=1)]).to_csv('playerstop10.csv')
'''

a = df_bron_games_all
b = df_steph_games_all
c = df_kobe_games_all
d = df_mike_games_all
e = df_shaq_games_all
f = df_kareem_games_all
g = df_wilt_games_all
h = df_magic_games_all
i = df_larry_games_all
j = df_kevin_games_all

data = {'Lebron': a,
         'Steph': b,
         'Kobe': c,
         'Mike': d,
         'Shaq': e,
         'Kareem': f,
         'Wilt': g,
         'Magic': h,
         'Larry': i,
         'Kevin': j}

df = pd.DataFrame.from_dict(data)

df.to_csv('out.csv')


#graveyard
'''
#from nba_api.stats.endpoints import leaguegamefinder
#this time we convert it to a dataframe in the same line of code
#GSW_games = leaguegamefinder.LeagueGameFinder(team_id_nullable=GSW_id).get_data_frames()[0]
#print("")
#print(GSW_games)

#Call the API endpoint passing in lebron's ID & which season 
gamelog_bron = playergamelog.PlayerGameLog(player_id='2544', season = '2018')

#Converts gamelog object into a pandas dataframe
#can also convert to JSON or dictionary  
df_bron_games_2018 = gamelog_bron.get_data_frames()

# If you want all seasons, you must import the SeasonAll parameter 
from nba_api.stats.library.parameters import SeasonAll

gamelog_bron_all = playergamelog.PlayerGameLog(player_id='2544', season = SeasonAll.all)

df_bron_games_all = gamelog_bron_all.get_data_frames()


use the command prompt
https://www.playingnumbers.com/2019/12/how-to-get-nba-data-using-the-nba_api-python-module-beginner/
https://community.mixpanel.com/sending-data-to-mixpanel-11/importerror-no-module-named-mixpanel-api-4393
#1: Lebron James
bron = [player for player in player_dict if player['full_name'] == 'LeBron James'][0]
bron_id = bron['id']
print(bron_id)
print("")

#now, we just to get the IDs of other players...
#above is the one we are looking for! - now we can get other players besides Lebron
#2: Stephen Curry
steph = [player for player in player_dict if player['full_name'] == 'Stephen Curry'][0]
steph_id = steph['id']
print(steph_id)
print("")

steph = [player for player in player_dict if player['full_name'] == 'Stephen Curry'][0]
steph_id = steph['id']
print(steph_id)
print("")

steph = [player for player in player_dict if player['full_name'] == 'Stephen Curry'][0]
steph_id = steph['id']
print(steph_id)
print("")

steph = [player for player in player_dict if player['full_name'] == 'Stephen Curry'][0]
steph_id = steph['id']
print(steph_id)
print("")

steph = [player for player in player_dict if player['full_name'] == 'Stephen Curry'][0]
steph_id = steph['id']
print(steph_id)
print("")

steph = [player for player in player_dict if player['full_name'] == 'Stephen Curry'][0]
steph_id = steph['id']
print(steph_id)
print("")

steph = [player for player in player_dict if player['full_name'] == 'Stephen Curry'][0]
steph_id = steph['id']
print(steph_id)
print("")

steph = [player for player in player_dict if player['full_name'] == 'Stephen Curry'][0]
steph_id = steph['id']
print(steph_id)
print("")

steph = [player for player in player_dict if player['full_name'] == 'Stephen Curry'][0]
steph_id = steph['id']
print(steph_id)
print("")


# find team Ids
from nba_api.stats.static import teams 
teams = teams.get_teams()
GSW = [x for x in teams if x['full_name'] == 'Golden State Warriors'][0]
GSW_id = GSW['id']
print(GSW_id)
print("")


# First we import the endpoint
# We will be using pandas dataframes to manipulate the data
from nba_api.stats.endpoints import playergamelog
import pandas as pd 

#Call the API endpoint passing in lebron's ID & which season 
gamelog_bron = playergamelog.PlayerGameLog(player_id='2544', season = '2018')

#Converts gamelog object into a pandas dataframe
#can also convert to JSON or dictionary  
df_bron_games_2018 = gamelog_bron.get_data_frames()
'''
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-7179a5f87b0e> in <module>()
#       1 # First we import the endpoint
#       2 # We will be using pandas dataframes to manipulate the data
# ----> 3 from nba_api.stats.endpoints import playergamelog
#       4 from nba_api.stats.static import players
#       5 import pandas as pd
#
# ModuleNotFoundError: No module named 'nba_api'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
